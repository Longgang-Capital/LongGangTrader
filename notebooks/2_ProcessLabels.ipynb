# %%
from py3lib import sarray
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from py3lib import sarray
#
# ModuleNotFoundError: No module named 'py3lib'

# %%
from py3lib import sarray

vwap_df = sarray.load('/local/yjhuang/mysapcache/kdaily_adj/avgprice.bin').df()
vwap_ret_1d = vwap_df.shift(-1) / vwap_df - 1
vwap_ret_5d = vwap_df.shift(-5) / vwap_df - 1
sarray.save_ndarray(vwap_ret_1d.values, '/local/yjhuang/mysapcache/labels/v2v_ret_1d.bin')
sarray.save_ndarray(vwap_ret_5d.values, '/local/yjhuang/mysapcache/labels/v2v_ret_5d.bin')
